# %% [markdown]
# # Enhance Gemini Model Capabilities: Challenge Lab

# %% [markdown]
# ## Challenge Scenario
#
# #### Cymbal Direct: Boosting Cymbal Direct's Retail Strategy with Gemini
#
# Cymbal Direct, the retail arm of Cymbal, wants to leverage the power of Gemini 2.5 Flash to gain a competitive edge in the basketball sneaker market. They aim to analyze competitor pricing, understand customer preferences, and generate synthetic data for testing new ecommerce features. You, as a data analyst, are tasked with using Gemini's capabilities to help Cymbal Direct achieve these goals. This will involve:
#   * **Code Execution**: Demonstrate the ability to execute Python code within Gemini 2.5 Flash
#   * **Grounding**: Use grounding to enhance the accuracy and relevance of Gemini's responses to questions about retail products.
#   * **Controlled Generation**: Retrieve information about basketball sneakers and their pricing from competitors using Google Search.
#   * **Synthetic Data Generation**: Structure the extracted product and pricing information into a predefined JSON schema.
#
# The goal is to provide Cymbal Direct with actionable insights to refine their marketing strategy, improve their products, and bolster product positioning. Are you ready for the challenge?

# %% [markdown]
# ## Task 1. Import libraries and install the Gen AI SDK
#
# In this section, you will import the libraries required for this lab and install the Google Gen AI SDK.
#
# **All cells have been written for you in this section. There are no `#TODOs` required.**

# %% [markdown]
# ### Install Google Gen AI SDK for Python

# %%
# %pip install --upgrade --quiet google-genai
# Out:
#   WARNING: Failed to remove contents in a temporary directory '/opt/conda/lib/python3.10/site-packages/google/~uth'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory '/opt/conda/lib/python3.10/site-packages/google/~auth2'.
#   You can safely remove it manually.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Restart current runtime
#
# To use the newly installed packages in this Jupyter runtime, you must restart the runtime. You can do this by running the cell below, which will restart the current kernel.

# %%
# Restart kernel after installs so that your environment can access the new packages
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %% [markdown]
# ### Import Libraries

# %%
from IPython.display import HTML, Markdown, display
from google import genai
from google.genai.types import (
    FunctionDeclaration,
    GenerateContentConfig,
    GoogleSearch,
    MediaResolution,
    Part,
    Retrieval,
    SafetySetting,
    Tool,
    ToolCodeExecution,
    ThinkingConfig,
    GenerateContentResponse,
    GenerateContentConfig,    
    VertexAISearch,
)
from collections.abc import Iterator
import os

# %% [markdown]
# ### Set Google Cloud project information and initialize Google Gen AI SDK

# %%
import os

PROJECT_ID = "qwiklabs-gcp-04-8de6c288c4e6"
LOCATION = os.environ.get("GOOGLE_CLOUD_REGION", "us-east4")
client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)

# %% [markdown]
# ### Load the Gemini 2.5 Flash model
#
# Learn more about all [Gemini models on Vertex AI](https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models#gemini-models).

# %%
MODEL_ID = "gemini-2.5-flash"  # @param {type: "string"}

# %% [markdown]
# ## Task 2.  Code Execution with Gemini 2.5 Flash
#
# In this task, you'll use the Gemini 2.5 Flash to write and execute Python code to perform a simple data analysis task, such as calculating the average price of a list of basketball sneakers.
#
# **Your tasks will be labeled with a `#TODO` section in the cell. Read each cell carefully and ensure you are filling them out correctly!**

# %% [markdown]
# ### Generate and Execute Code using Gemini 2.5 Flash

# %% [markdown]
# Use the following sneaker pricing data to generate and execute Python code that tells you the **average price** of the sneakers in the list:
#
# sneaker_prices = [120, 150, 110, 180, 135]

# %%
from google.genai.types import GenerateContentConfig, Tool, ToolCodeExecution

# 1. Define the code execution tool
code_execution_tool = Tool(code_execution=ToolCodeExecution()) #TODO: Define the code execution tool

sneaker_prices = [120, 150, 110, 180, 135, 95, 210, 170, 140, 165] 

# 2. Define the prompt with the code to be executed
PROMPT = f"""What is the average price of sneakers in {sneaker_prices}
Generate and run code for the calculation."""

response = client.models.generate_content(
    model=MODEL_ID,
    contents=PROMPT,
    config=GenerateContentConfig(
        tools=[code_execution_tool],
        temperature=0,
    ),
)

# %% [markdown]
# ### View the generated code
#
# Write code in the #TODO portions to iterate through the response and display any generated Python code by checking for `part.executable_code` in the response parts:

# %%
for part in response.candidates[0].content.parts:
    if part.executable_code:
        display(
            Markdown(
                f"""
```py
{part.executable_code.code}
```
"""
            )
        )
# Out:
# ```py
# prices = [120, 150, 110, 180, 135, 95, 210, 170, 140, 165]
# average_price = sum(prices) / len(prices)
# print(f'{average_price=}')
#
# ```

# %% [markdown]
# ### View the code execution results
#
# Write code in the #TODO portions that iterates through the response and displays the execution result and outcome by checking for `part.code_execution_result` in the response parts:

# %%
for part in response.candidates[0].content.parts:
    if part.code_execution_result:
        display(Markdown(f"`{part.code_execution_result.output}`"))
        print("\nOutcome:", part.code_execution_result.outcome)
# Out:
# `average_price=147.5
# `
# Outcome: Outcome.OUTCOME_OK

# %% [markdown]
# ## Task 3. Grounding with Google Search
#
# In this task, you'll use Gemini 2.5 Flash with grounding to enhance the accuracy and relevance of Gemini's responses to questions about retail products.
#
# **Your tasks will be labeled with a `#TODO` section in the cell. Read each cell carefully and ensure you are filling them out correctly!**

# %% [markdown]
# ### Grounding based on search results
#
# Ask Gemini a question about a specific basketball sneaker model (e.g., "What are the key features of the Nike Air Jordan XXXVI?"), using grounding to ensure the response is based on factual information from the web.

# %%
from google.genai.types import GenerateContentConfig, GoogleSearch, Tool

# 1. Define the Google Search tool
google_search_tool = Tool(google_search=GoogleSearch())

# 2. Define the prompt with grounding
prompt = "What are the key features of the Nike Air Jordan XXXVI?"

# 3. Generate a response with grounding
response = client.models.generate_content(
    model=MODEL_ID,
    contents=prompt,
    config=GenerateContentConfig(tools=[google_search_tool]), # TODO: Define the config,
)

# Print the response
print(response.text)
# Out:
# The Nike Air Jordan XXXVI (36) is engineered with a strong emphasis on lightweight design, responsiveness, and support for basketball performance. Key features include:
#
# *   **Jacquard Leno-Weave Upper** The upper is constructed from a jacquard leno-weave material, which is exceptionally light, breathable, and flexible while still providing ample support and stability for quick movements on the court. Its slightly open weave allows light to pass through, contributing to its lightweight aesthetic.
# *   **Full-Length Zoom Air Strobel Unit** A full-length Zoom Air Strobel unit is stitched directly to the upper, placing the cushioning directly underfoot for enhanced responsiveness and a closer-to-the-ground feel.
# *   **Forefoot Zoom Air Unit** In addition to the Strobel unit, a large Zoom Air unit is strategically placed under the forefoot, providing an extra boost of responsiveness and bounce.
# *   **Hollowed-Out Eclipse Plate** The Eclipse Plate, carried over from previous Jordan models (like the 34 and 35), is further refined in the XXXVI. It's hollowed out between the midsole and outsole, reducing weight and exposing the shoe's stabilizing shank, which helps prevent twisting.
# *   **Herringbone Traction Pattern** The outsole features a durable herringbone traction pattern with thick grooves, a tried-and-true design that ensures multi-directional grip and helps prevent dust clogging.
# *   **Lightweight Construction** The overall design prioritizes weight reduction, with elements like the leno-weave upper, perforated sockliner, and refined Eclipse Plate contributing to making it one of the lightest Air Jordans to date.
# *   **Design Homage to Air Jordan 6** The Air Jordan XXXVI incorporates subtle design cues from the iconic Air Jordan 6, such as a heel tab and lace covering, as an homage to the shoe Michael Jordan wore when he won his first championship.
# *   **Flexible Tongue with Padding** Both high and low-top versions include a flexible tongue with padding to help reduce pressure from the laces on the ankle and foot.

# %% [markdown]
# ## Task 4. Extract Competitor Pricing and Structure Response with JSON Schema
#
# In this task, you'll use Gemini 2.5 Flash to retrieve information about a basketball sneaker and its pricing sold by a competitor, returning the data in a structured format using a provided JSON schema.
#
# **Your tasks will be labeled with a `#TODO` section in the cell. Read each cell carefully and ensure you are filling them out correctly!**

# %%
response_schema = {
    "type": "object",
    "properties": {
        "answer": {
            "type": "string",
            "description": "The answer to the user's question."
        },
        "originalQuery": {
            "type": "string",
            "description": "The original query from the user."
        },
        "productName": {
            "type": "string",
            "description": "The name of the product."
        },
        "price": {
          "type": "number",
          "description": "The price of the product."
        }    
        },
    "required": ["originalQuery", "productName", "price"]
}

# %%
from google.genai.types import GenerateContentConfig, GoogleSearch, Tool
from IPython.display import Markdown, display
import json

# 1. Define the basketball sneaker models
sneaker_models = ["Under Armour Curry Flow 9", "Sketchers Slip-ins: Glide-Step Pro"]

# 2. Define the online retailers
retailers = ["Foot Locker", "Nordstrom"]

# 3. Initialize an empty list to store the extracted data
extracted_data = []

# 4. Loop through the sneaker models and retailers to extract pricing information
for model in sneaker_models:
    for retailer in retailers:
        # 5. Construct the search query
        query = f"{model} price at {retailer}" "If the price found is 0.00 return a random value between $50 and $200. DO NOT return 0.00"
        #TODO: Define the prompt to search stores for sneaker models and find pricing. Leave the second sentence in the prompt. (If the price found is 0.00 return a random value between $50 and $200. DO NOT return 0.00)

        # 6. Use Response Schema to extract the data
        response = client.models.generate_content(
            model=MODEL_ID,
            contents=query,
            config=GenerateContentConfig(
                response_schema=response_schema, #TODO: Define the response schema,
                response_mime_type="application/json"
            )
        )
        
        print(response.text)
# Out:
# {"originalQuery": "Under Armour Curry Flow 9 price at Foot Locker", "productName": "Under Armour Curry Flow 9", "price": 160.00}
# {"originalQuery": "Under Armour Curry Flow 9 price at Nordstrom", "productName": "Under Armour Curry Flow 9", "price": 160.00}
# {
#   "answer": "The price for Sketchers Slip-ins: Glide-Step Pro at Foot Locker is approximately $123.45, as a specific price was not found. Please check Foot Locker directly for the most current information.",
#   "originalQuery": "Sketchers Slip-ins: Glide-Step Pro price at Foot Locker",
#   "productName": "Sketchers Slip-ins: Glide-Step Pro",
#   "price": 123.45
# }
# {
#   "answer": "The Sketchers Slip-ins: Glide-Step Pro are priced at 95.50 at Nordstrom.",
#   "originalQuery": "Sketchers Slip-ins: Glide-Step Pro price at Nordstrom",
#   "productName": "Sketchers Slip-ins: Glide-Step Pro",
#   "price": 95.50
# }
